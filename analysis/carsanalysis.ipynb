# %%
import pandas as pd
import sqlite3

# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("../data/db.db")
df = pd.read_sql_query("SELECT * from CarPostings", con)
df = df[df['price'] <= 500_000] # Filter out outliers
df = df[df['mileage'] <= 500_000] # Filter out outliers
df = df[df['year_of_production'] >= 1990] # Filter out outliers


# Verify that result of SQL query is stored in the dataframe
print(df.head())

con.close()
# Out:
#    Id      car_brand         model  year_of_production  mileage    price  \
# 0  31           Audi      A6 Avant                2012   209000  13300.0
# 1  32  Mercedes-Benz       CLA 250                2015   157000  11500.0
# 2  33           Audi            Q7                2006   232500   7999.0
# 3  34  Mercedes-Benz          S550                2011   225000  14500.0
# 4  35           Audi  A6 Limousine                2015   201000  13999.0
#
#    is_automatic_transmission_type         shop  \
# 0                             NaN  kentavar.bg
# 1                             1.0  kentavar.bg
# 2                             1.0  kentavar.bg
# 3                             1.0  kentavar.bg
# 4                             1.0  kentavar.bg
#
#                                               source         MIS_DT  \
# 0  https://www.kentavar.bg/prodajba-na-avtomobili...  1777556574187
# 1  https://www.kentavar.bg/prodajba-na-avtomobili...  1777556634012
# ...

# %%
# Analysis by brand
import plotly.express as px

df1 = df[["car_brand", "price", "mileage", "year_of_production"]].groupby(["car_brand"]).mean()
df1 = df1.sort_values(by=["price"], ascending=False)
df1.head(100)
# Out:
#                      price        mileage  year_of_production
# car_brand
# Ferrari      379040.800000   19778.400000         2023.000000
# Lamborghini  259958.000000   31601.333333         2020.333333
# McLaren      171259.168000   22589.000000         2021.800000
# Bentley       91616.500000  107400.000000         2015.833333
# Voyah         82900.000000    6000.000000         2026.000000
# ...                    ...            ...                 ...
# Daewoo         2999.000000   12500.000000         2004.000000
# Tata           2700.000000  155000.000000         2009.000000
# Dr             2475.000000  202700.000000         2009.000000
# Rover          1383.333333  238666.666667         2001.333333
# BAW            1200.000000  256806.000000         2002.000000
#
# [91 rows x 3 columns]

# %%
px.scatter(df1, x="year_of_production", y="price", trendline="ols",
           title="Mean price by year of production on brand level")

# %%
# Trend analysis

px.scatter(df, x="year_of_production", y="price", trendline="ols")

# %%
px.scatter(df, x="mileage", y="price", trendline="ols")
